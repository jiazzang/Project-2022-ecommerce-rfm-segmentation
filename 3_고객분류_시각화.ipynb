# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style('darkgrid')
plt.style.use('seaborn')

# %%
# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
## 데이터 불러오기
records = pd.read_csv('C:/Users/User/Desktop/프로젝트/data/records.csv')
customer_stats = pd.read_csv('C:/Users/User/Desktop/프로젝트/data/customer_stats.csv')

# %% [markdown]
# ## 고객 분류

# %% [markdown]
# ### VIP 고객

# %% [markdown]
# #### segment별 고객 수

# %%
VIP = pd.DataFrame({'segment': ['Consumer', 'Corporate', 'Home Office'], 
              'segment_count': [39, 34, 20]})
VIP
# Out:
#        segment  segment_count
# 0     Consumer             39
# 1    Corporate             34
# 2  Home Office             20

# %% [markdown]
# ##### 도넛 차트

# %%
# 데이터 준비
labels = VIP['segment']
frequency = VIP['segment_count']

fig = plt.figure(figsize=(7,7))   # 캔버스 생성
fig.set_facecolor('white')        # 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot()            # 프레임 생성

pie = ax.pie(frequency, startangle=90, counterclock=False,  
             shadow=True, wedgeprops=dict(width=0.5))  # 반지름 0.5 짜리 구멍
total = np.sum(frequency)    # 빈도수 총합

sum_pct = 0      # 백분율 초기값
for i, l in enumerate(labels):
    ang1, ang2 = pie[0][i].theta1, pie[0][i].theta2    # 각1, 각2
    r = pie[0][i].r    # 원의 반지름
    
    x = ((r+0.5)/2)*np.cos(np.pi/180*((ang1+ang2)/2))     # 정중앙 x좌표
    y = ((r+0.5)/2)*np.sin(np.pi/180*((ang1+ang2)/2))     # 정중앙 y좌표
    
    if i < len(labels) - 1:
        sum_pct += float(f'{frequency[i]/total*100:.1f}')     # 백분율을 누적한다.
        ax.text(x,y,f'{frequency[i]/total*100:.1f}%',ha='center',va='center')     # 백분율 텍스트 표시
    else:              # 총합을 100으로 맞추기 위해 마지막 백분율은 100에서 백분율 누적값을 빼준다.
        ax.text(x,y,f'{100-sum_pct:.1f}%',ha='center',va='center') 

plt.title('segment별 고객 수', size=18)
plt.legend(pie[0],labels, fontsize=12)

plt.show()

# %% [markdown]
# #### 카테고리별 주문 수

# %%
order_count = pd.DataFrame({'category': ['Office Supplies', 'Technology', 'Furniture'], 
              'order_count': [466, 185, 182]})
order_count
# Out:
#           category  order_count
# 0  Office Supplies          466
# 1       Technology          185
# 2        Furniture          182

# %%
# 데이터 준비
labels = order_count['category']
frequency = order_count['order_count']

fig = plt.figure(figsize=(7,7))   # 캔버스 생성
fig.set_facecolor('white')        # 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot()            # 프레임 생성

pie = ax.pie(frequency, startangle=90, counterclock=False,  
             shadow=True, colors=['mediumspringgreen', 'paleturquoise', 'violet'], 
             wedgeprops=dict(width=0.5))  # 반지름 0.5 짜리 구멍
total = np.sum(frequency)    # 빈도수 총합

sum_pct = 0      # 백분율 초기값
for i, l in enumerate(labels):
    ang1, ang2 = pie[0][i].theta1, pie[0][i].theta2    # 각1, 각2
    r = pie[0][i].r    # 원의 반지름
    
    x = ((r+0.5)/2)*np.cos(np.pi/180*((ang1+ang2)/2))     # 정중앙 x좌표
    y = ((r+0.5)/2)*np.sin(np.pi/180*((ang1+ang2)/2))     # 정중앙 y좌표
    
    if i < len(labels) - 1:
        sum_pct += float(f'{frequency[i]/total*100:.1f}')     # 백분율을 누적한다.
        ax.text(x,y,f'{frequency[i]/total*100:.1f}%',ha='center',va='center')     # 백분율 텍스트 표시
    else:              # 총합을 100으로 맞추기 위해 마지막 백분율은 100에서 백분율 누적값을 빼준다.
        ax.text(x,y,f'{100-sum_pct:.1f}%',ha='center',va='center') 

plt.title('카테고리별 주문 수', size=18)
plt.legend(pie[0],labels, fontsize=12)

plt.show()

# %% [markdown]
# #### 카테고리별 매출액

# %%
sum_sales = pd.DataFrame({'category': ['Office Supplies', 'Technology', 'Furniture'], 
              'sum_sales': [85786.74, 101759.8, 73531.78]})
sum_sales
# Out:
#           category  sum_sales
# 0  Office Supplies   85786.74
# 1       Technology  101759.80
# 2        Furniture   73531.78

# %%
# 데이터 준비
labels = sum_sales['category']
frequency = sum_sales['sum_sales']

fig = plt.figure(figsize=(7,7))   # 캔버스 생성
fig.set_facecolor('white')        # 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot()            # 프레임 생성

pie = ax.pie(frequency, startangle=90, counterclock=False,  
             shadow=True, colors=['mediumspringgreen', 'paleturquoise', 'violet'], 
             wedgeprops=dict(width=0.5))  # 반지름 0.5 짜리 구멍
total = np.sum(frequency)    # 빈도수 총합

sum_pct = 0      # 백분율 초기값
for i, l in enumerate(labels):
    ang1, ang2 = pie[0][i].theta1, pie[0][i].theta2    # 각1, 각2
    r = pie[0][i].r    # 원의 반지름
    
    x = ((r+0.5)/2)*np.cos(np.pi/180*((ang1+ang2)/2))     # 정중앙 x좌표
    y = ((r+0.5)/2)*np.sin(np.pi/180*((ang1+ang2)/2))     # 정중앙 y좌표
    
    if i < len(labels) - 1:
        sum_pct += float(f'{frequency[i]/total*100:.1f}')     # 백분율을 누적한다.
        ax.text(x,y,f'{frequency[i]/total*100:.1f}%',ha='center',va='center')     # 백분율 텍스트 표시
    else:              # 총합을 100으로 맞추기 위해 마지막 백분율은 100에서 백분율 누적값을 빼준다.
        ax.text(x,y,f'{100-sum_pct:.1f}%',ha='center',va='center') 

plt.title('카테고리별 매출액', size=18)
plt.legend(pie[0],labels, fontsize=12)

plt.show()

# %% [markdown]
# ### 떠나간 VIP 고객

# %% [markdown]
# #### segment별 고객 수

# %%
leave_VIP = pd.DataFrame({'segment': ['Consumer', 'Corporate', 'Home Office'], 
              'segment_count': [8, 10, 3]})
leave_VIP
# Out:
#        segment  segment_count
# 0     Consumer              8
# 1    Corporate             10
# 2  Home Office              3

# %% [markdown]
# ##### 도넛 차트

# %%
# 데이터 준비
labels = leave_VIP['segment']
frequency = leave_VIP['segment_count']

fig = plt.figure(figsize=(7,7))   # 캔버스 생성
fig.set_facecolor('white')        # 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot()            # 프레임 생성

pie = ax.pie(frequency, startangle=90, counterclock=False,  
             shadow=True, wedgeprops=dict(width=0.5))  # 반지름 0.5 짜리 구멍
total = np.sum(frequency)    # 빈도수 총합

sum_pct = 0      # 백분율 초기값
for i, l in enumerate(labels):
    ang1, ang2 = pie[0][i].theta1, pie[0][i].theta2    # 각1, 각2
    r = pie[0][i].r    # 원의 반지름
    
    x = ((r+0.5)/2)*np.cos(np.pi/180*((ang1+ang2)/2))     # 정중앙 x좌표
    y = ((r+0.5)/2)*np.sin(np.pi/180*((ang1+ang2)/2))     # 정중앙 y좌표
    
    if i < len(labels) - 1:
        sum_pct += float(f'{frequency[i]/total*100:.1f}')     # 백분율을 누적한다.
        ax.text(x,y,f'{frequency[i]/total*100:.1f}%',ha='center',va='center')     # 백분율 텍스트 표시
    else:              # 총합을 100으로 맞추기 위해 마지막 백분율은 100에서 백분율 누적값을 빼준다.
        ax.text(x,y,f'{100-sum_pct:.1f}%',ha='center',va='center') 

plt.title('segment별 고객 수', size=18)
plt.legend(pie[0],labels, fontsize=12)

plt.show()

# %% [markdown]
# #### 카테고리별 주문 수

# %%
order_count = pd.DataFrame({'category': ['Office Supplies', 'Technology', 'Furniture'], 
              'order_count': [75, 38, 49]})
order_count
# Out:
#           category  order_count
# 0  Office Supplies           75
# 1       Technology           38
# 2        Furniture           49

# %%
# 데이터 준비
labels = order_count['category']
frequency = order_count['order_count']

fig = plt.figure(figsize=(7,7))   # 캔버스 생성
fig.set_facecolor('white')        # 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot()            # 프레임 생성

pie = ax.pie(frequency, startangle=90, counterclock=False,  
             shadow=True, colors=['mediumspringgreen', 'paleturquoise', 'violet'], 
             wedgeprops=dict(width=0.5))  # 반지름 0.5 짜리 구멍
total = np.sum(frequency)    # 빈도수 총합

sum_pct = 0      # 백분율 초기값
for i, l in enumerate(labels):
    ang1, ang2 = pie[0][i].theta1, pie[0][i].theta2    # 각1, 각2
    r = pie[0][i].r    # 원의 반지름
    
    x = ((r+0.5)/2)*np.cos(np.pi/180*((ang1+ang2)/2))     # 정중앙 x좌표
    y = ((r+0.5)/2)*np.sin(np.pi/180*((ang1+ang2)/2))     # 정중앙 y좌표
    
    if i < len(labels) - 1:
        sum_pct += float(f'{frequency[i]/total*100:.1f}')     # 백분율을 누적한다.
        ax.text(x,y,f'{frequency[i]/total*100:.1f}%',ha='center',va='center')     # 백분율 텍스트 표시
    else:              # 총합을 100으로 맞추기 위해 마지막 백분율은 100에서 백분율 누적값을 빼준다.
        ax.text(x,y,f'{100-sum_pct:.1f}%',ha='center',va='center') 

plt.title('카테고리별 주문 수', size=18)
plt.legend(pie[0],labels, fontsize=12)

plt.show()

# %% [markdown]
# #### 카테고리별 매출액

# %%
sum_sales = pd.DataFrame({'category': ['Office Supplies', 'Technology', 'Furniture'], 
              'sum_sales': [17459.54, 24295.26, 29737.35]})
sum_sales
# Out:
#           category  sum_sales
# 0  Office Supplies   17459.54
# 1       Technology   24295.26
# 2        Furniture   29737.35

# %%
# 데이터 준비
labels = sum_sales['category']
frequency = sum_sales['sum_sales']

fig = plt.figure(figsize=(7,7))   # 캔버스 생성
fig.set_facecolor('white')        # 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot()            # 프레임 생성

pie = ax.pie(frequency, startangle=90, counterclock=False,  
             shadow=True, colors=['mediumspringgreen', 'paleturquoise', 'violet'], 
             wedgeprops=dict(width=0.5))  # 반지름 0.5 짜리 구멍
total = np.sum(frequency)    # 빈도수 총합

sum_pct = 0      # 백분율 초기값
for i, l in enumerate(labels):
    ang1, ang2 = pie[0][i].theta1, pie[0][i].theta2    # 각1, 각2
    r = pie[0][i].r    # 원의 반지름
    
    x = ((r+0.5)/2)*np.cos(np.pi/180*((ang1+ang2)/2))     # 정중앙 x좌표
    y = ((r+0.5)/2)*np.sin(np.pi/180*((ang1+ang2)/2))     # 정중앙 y좌표
    
    if i < len(labels) - 1:
        sum_pct += float(f'{frequency[i]/total*100:.1f}')     # 백분율을 누적한다.
        ax.text(x,y,f'{frequency[i]/total*100:.1f}%',ha='center',va='center')     # 백분율 텍스트 표시
    else:              # 총합을 100으로 맞추기 위해 마지막 백분율은 100에서 백분율 누적값을 빼준다.
        ax.text(x,y,f'{100-sum_pct:.1f}%',ha='center',va='center') 

plt.title('카테고리별 매출액', size=18)
plt.legend(pie[0],labels, fontsize=12)

plt.show()

# %% [markdown]
# #### 고객별 구매주기

# %%
df1 = pd.read_csv('C:/Users/User/Desktop/프로젝트/data/떠나간_VIP_구매주기.csv')
df1.head(2)
# Out:
#   customer_id  order_cycle_avg
# 0    AM-10705             54.0
# 1    AR-10405             49.5

# %%
print(df1['order_cycle_avg'].mean())
print(df1['order_cycle_avg'].median())
# Out:
# 58.76587142857143
# 54.0

# %% [markdown]
# ### 최근, 자주 구매한 고객

# %% [markdown]
# #### segment별 고객 수

# %%
lately_often = pd.DataFrame({'segment': ['Consumer', 'Corporate', 'Home Office'], 
              'segment_count': [89, 36, 22]})
lately_often
# Out:
#        segment  segment_count
# 0     Consumer             89
# 1    Corporate             36
# 2  Home Office             22

# %% [markdown]
# ##### 도넛 차트

# %%
# 데이터 준비
labels = lately_often['segment']
frequency = lately_often['segment_count']

fig = plt.figure(figsize=(7,7))   # 캔버스 생성
fig.set_facecolor('white')        # 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot()            # 프레임 생성

pie = ax.pie(frequency, startangle=90, counterclock=False,  
             shadow=True, wedgeprops=dict(width=0.5))  # 반지름 0.5 짜리 구멍
total = np.sum(frequency)    # 빈도수 총합

sum_pct = 0      # 백분율 초기값
for i, l in enumerate(labels):
    ang1, ang2 = pie[0][i].theta1, pie[0][i].theta2    # 각1, 각2
    r = pie[0][i].r    # 원의 반지름
    
    x = ((r+0.5)/2)*np.cos(np.pi/180*((ang1+ang2)/2))     # 정중앙 x좌표
    y = ((r+0.5)/2)*np.sin(np.pi/180*((ang1+ang2)/2))     # 정중앙 y좌표
    
    if i < len(labels) - 1:
        sum_pct += float(f'{frequency[i]/total*100:.1f}')     # 백분율을 누적한다.
        ax.text(x,y,f'{frequency[i]/total*100:.1f}%',ha='center',va='center')     # 백분율 텍스트 표시
    else:              # 총합을 100으로 맞추기 위해 마지막 백분율은 100에서 백분율 누적값을 빼준다.
        ax.text(x,y,f'{100-sum_pct:.1f}%',ha='center',va='center') 

plt.title('segment별 고객 수', size=18)
plt.legend(pie[0],labels, fontsize=12)

plt.show()

# %% [markdown]
# #### 카테고리별 주문 수

# %%
order_count = pd.DataFrame({'category': ['Office Supplies', 'Technology', 'Furniture'], 
              'order_count': [603, 142, 181]})
order_count
# Out:
#           category  order_count
# 0  Office Supplies          603
# 1       Technology          142
# 2        Furniture          181

# %%
# 데이터 준비
labels = order_count['category']
frequency = order_count['order_count']

fig = plt.figure(figsize=(7,7))   # 캔버스 생성
fig.set_facecolor('white')        # 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot()            # 프레임 생성

pie = ax.pie(frequency, startangle=90, counterclock=False,  
             shadow=True, colors=['mediumspringgreen', 'paleturquoise', 'violet'], 
             wedgeprops=dict(width=0.5))  # 반지름 0.5 짜리 구멍
total = np.sum(frequency)    # 빈도수 총합

sum_pct = 0      # 백분율 초기값
for i, l in enumerate(labels):
    ang1, ang2 = pie[0][i].theta1, pie[0][i].theta2    # 각1, 각2
    r = pie[0][i].r    # 원의 반지름
    
    x = ((r+0.5)/2)*np.cos(np.pi/180*((ang1+ang2)/2))     # 정중앙 x좌표
    y = ((r+0.5)/2)*np.sin(np.pi/180*((ang1+ang2)/2))     # 정중앙 y좌표
    
    if i < len(labels) - 1:
        sum_pct += float(f'{frequency[i]/total*100:.1f}')     # 백분율을 누적한다.
        ax.text(x,y,f'{frequency[i]/total*100:.1f}%',ha='center',va='center')     # 백분율 텍스트 표시
    else:              # 총합을 100으로 맞추기 위해 마지막 백분율은 100에서 백분율 누적값을 빼준다.
        ax.text(x,y,f'{100-sum_pct:.1f}%',ha='center',va='center') 

plt.title('카테고리별 주문 수', size=18)
plt.legend(pie[0],labels, fontsize=12)

plt.show()

# %% [markdown]
# #### 카테고리별 매출액

# %%
sum_sales = pd.DataFrame({'category': ['Office Supplies', 'Technology', 'Furniture'], 
              'sum_sales': [40612.32, 23935.23, 32311.12]})
sum_sales
# Out:
#           category  sum_sales
# 0  Office Supplies   40612.32
# 1       Technology   23935.23
# 2        Furniture   32311.12

# %%
# 데이터 준비
labels = sum_sales['category']
frequency = sum_sales['sum_sales']

fig = plt.figure(figsize=(7,7))   # 캔버스 생성
fig.set_facecolor('white')        # 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot()            # 프레임 생성

pie = ax.pie(frequency, startangle=90, counterclock=False,  
             shadow=True, colors=['mediumspringgreen', 'paleturquoise', 'violet'], 
             wedgeprops=dict(width=0.5))  # 반지름 0.5 짜리 구멍
total = np.sum(frequency)    # 빈도수 총합

sum_pct = 0      # 백분율 초기값
for i, l in enumerate(labels):
    ang1, ang2 = pie[0][i].theta1, pie[0][i].theta2    # 각1, 각2
    r = pie[0][i].r    # 원의 반지름
    
    x = ((r+0.5)/2)*np.cos(np.pi/180*((ang1+ang2)/2))     # 정중앙 x좌표
    y = ((r+0.5)/2)*np.sin(np.pi/180*((ang1+ang2)/2))     # 정중앙 y좌표
    
    if i < len(labels) - 1:
        sum_pct += float(f'{frequency[i]/total*100:.1f}')     # 백분율을 누적한다.
        ax.text(x,y,f'{frequency[i]/total*100:.1f}%',ha='center',va='center')     # 백분율 텍스트 표시
    else:              # 총합을 100으로 맞추기 위해 마지막 백분율은 100에서 백분율 누적값을 빼준다.
        ax.text(x,y,f'{100-sum_pct:.1f}%',ha='center',va='center') 

plt.title('카테고리별 매출액', size=18)
plt.legend(pie[0],labels, fontsize=12)

plt.show()

# %% [markdown]
# ### 최근, 많은 금액을 지불한 고객

# %% [markdown]
# #### segment별 고객 수

# %%
lately_high = pd.DataFrame({'segment': ['Consumer', 'Corporate', 'Home Office'], 
              'segment_count': [20, 12, 13]})
lately_high
# Out:
#        segment  segment_count
# 0     Consumer             20
# 1    Corporate             12
# 2  Home Office             13

# %% [markdown]
# ##### 도넛 차트

# %%
# 데이터 준비
labels = lately_high['segment']
frequency = lately_high['segment_count']

fig = plt.figure(figsize=(7,7))   # 캔버스 생성
fig.set_facecolor('white')        # 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot()            # 프레임 생성

pie = ax.pie(frequency, startangle=90, counterclock=False,  
             shadow=True, wedgeprops=dict(width=0.5))  # 반지름 0.5 짜리 구멍
total = np.sum(frequency)    # 빈도수 총합

sum_pct = 0      # 백분율 초기값
for i, l in enumerate(labels):
    ang1, ang2 = pie[0][i].theta1, pie[0][i].theta2    # 각1, 각2
    r = pie[0][i].r    # 원의 반지름
    
    x = ((r+0.5)/2)*np.cos(np.pi/180*((ang1+ang2)/2))     # 정중앙 x좌표
    y = ((r+0.5)/2)*np.sin(np.pi/180*((ang1+ang2)/2))     # 정중앙 y좌표
    
    if i < len(labels) - 1:
        sum_pct += float(f'{frequency[i]/total*100:.1f}')     # 백분율을 누적한다.
        ax.text(x,y,f'{frequency[i]/total*100:.1f}%',ha='center',va='center')     # 백분율 텍스트 표시
    else:              # 총합을 100으로 맞추기 위해 마지막 백분율은 100에서 백분율 누적값을 빼준다.
        ax.text(x,y,f'{100-sum_pct:.1f}%',ha='center',va='center') 

plt.title('segment별 고객 수', size=18)
plt.legend(pie[0],labels, fontsize=12)

plt.show()

# %% [markdown]
# #### 카테고리별 주문 수

# %%
order_count = pd.DataFrame({'category': ['Office Supplies', 'Technology', 'Furniture'], 
              'order_count': [107, 53, 54]})
order_count
# Out:
#           category  order_count
# 0  Office Supplies          107
# 1       Technology           53
# 2        Furniture           54

# %%
# 데이터 준비
labels = order_count['category']
frequency = order_count['order_count']

fig = plt.figure(figsize=(7,7))   # 캔버스 생성
fig.set_facecolor('white')        # 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot()            # 프레임 생성

pie = ax.pie(frequency, startangle=90, counterclock=False,  
             shadow=True, colors=['mediumspringgreen', 'paleturquoise', 'violet'], 
             wedgeprops=dict(width=0.5))  # 반지름 0.5 짜리 구멍
total = np.sum(frequency)    # 빈도수 총합

sum_pct = 0      # 백분율 초기값
for i, l in enumerate(labels):
    ang1, ang2 = pie[0][i].theta1, pie[0][i].theta2    # 각1, 각2
    r = pie[0][i].r    # 원의 반지름
    
    x = ((r+0.5)/2)*np.cos(np.pi/180*((ang1+ang2)/2))     # 정중앙 x좌표
    y = ((r+0.5)/2)*np.sin(np.pi/180*((ang1+ang2)/2))     # 정중앙 y좌표
    
    if i < len(labels) - 1:
        sum_pct += float(f'{frequency[i]/total*100:.1f}')     # 백분율을 누적한다.
        ax.text(x,y,f'{frequency[i]/total*100:.1f}%',ha='center',va='center')     # 백분율 텍스트 표시
    else:              # 총합을 100으로 맞추기 위해 마지막 백분율은 100에서 백분율 누적값을 빼준다.
        ax.text(x,y,f'{100-sum_pct:.1f}%',ha='center',va='center') 

plt.title('카테고리별 주문 수', size=18)
plt.legend(pie[0],labels, fontsize=12)

plt.show()

# %% [markdown]
# #### 카테고리별 매출액

# %%
sum_sales = pd.DataFrame({'category': ['Office Supplies', 'Technology', 'Furniture'], 
              'sum_sales': [34380.2, 64189.57, 30394.26]})
sum_sales
# Out:
#           category  sum_sales
# 0  Office Supplies   34380.20
# 1       Technology   64189.57
# 2        Furniture   30394.26

# %%
# 데이터 준비
labels = sum_sales['category']
frequency = sum_sales['sum_sales']

fig = plt.figure(figsize=(7,7))   # 캔버스 생성
fig.set_facecolor('white')        # 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot()            # 프레임 생성

pie = ax.pie(frequency, startangle=90, counterclock=False,  
             shadow=True, colors=['mediumspringgreen', 'paleturquoise', 'violet'], 
             wedgeprops=dict(width=0.5))  # 반지름 0.5 짜리 구멍
total = np.sum(frequency)    # 빈도수 총합

sum_pct = 0      # 백분율 초기값
for i, l in enumerate(labels):
    ang1, ang2 = pie[0][i].theta1, pie[0][i].theta2    # 각1, 각2
    r = pie[0][i].r    # 원의 반지름
    
    x = ((r+0.5)/2)*np.cos(np.pi/180*((ang1+ang2)/2))     # 정중앙 x좌표
    y = ((r+0.5)/2)*np.sin(np.pi/180*((ang1+ang2)/2))     # 정중앙 y좌표
    
    if i < len(labels) - 1:
        sum_pct += float(f'{frequency[i]/total*100:.1f}')     # 백분율을 누적한다.
        ax.text(x,y,f'{frequency[i]/total*100:.1f}%',ha='center',va='center')     # 백분율 텍스트 표시
    else:              # 총합을 100으로 맞추기 위해 마지막 백분율은 100에서 백분율 누적값을 빼준다.
        ax.text(x,y,f'{100-sum_pct:.1f}%',ha='center',va='center') 

plt.title('카테고리별 매출액', size=18)
plt.legend(pie[0],labels, fontsize=12)

plt.show()

# %% [markdown]
# ### 과거에 많은 금액을 지불한 고객

# %% [markdown]
# #### 월별 구매횟수

# %%
order_count = pd.DataFrame({'order_month': ['2020-01', '2020-02', '2020-03', '2020-05', 
                                       '2020-06', '2020-07', '2020-08'], 
              'order_count': [2, 1, 4, 3, 4, 3, 2]})
order_count
# Out:
#   order_month  order_count
# 0     2020-01            2
# 1     2020-02            1
# 2     2020-03            4
# 3     2020-05            3
# 4     2020-06            4
# 5     2020-07            3
# 6     2020-08            2

# %%
## bar chart
labels = order_count['order_month']
points = order_count['order_count']

fig = plt.figure(figsize=(8,6))
fig.set_facecolor('white')
ax = fig.add_subplot()

bar = ax.bar(labels, points)

# 그래프에 값 표시하기
for i, v in enumerate(labels):
    plt.text(v, points[i], points[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 13, 
             color='black',
             horizontalalignment='center',
             verticalalignment='bottom')

plt.xlabel('구매 월', fontsize=12)
plt.ylabel('고객수', fontsize=12)
plt.title('월별 구매횟수', fontsize=17)
plt.show()
